# %% [markdown]
# # Linux Basics (Cyber Guy)
#
# > man "command" >> to get the command help or manual
#
# >> Basic Commands:
#    - pwd >> Print Working Directory
#    - ls >> List the files
#    - ls -l >> List the files with its permisions
#    - ls -a >> List all the files included the hidden
#    - ls -la >> List all the files included the hidden with permisions
#    - cd "File - Direct" >> Change your Directory
#    - cd "space" >> to go Home
#    - cd .. >> to go back one directory
#    - clear >> to Clean the Terminal screen
#    - Ctrl + L >> to Scroll to blanc Terminal screen
#    - cat "file_name" >> to show its content
#    - nano "file_name" >> to show content and edit it
#    - sudo apt update >> update the system files
#    - sudo su >> to be a super user
#    - uname -a >> to know the Version of your linux
#    - history -c >> to clear the saved commands history
#
#
# >> Creating, Removing, Moving, Coping Files and Directories:
#    - touch "file_name" >> to Create a file
#    - touch ".file_name" >> to Create a Hidden file
#    - rm "file_name" >> to Remove a file
#
#    - mkdire "Dire_name" >> to make a directory
#    - rmdir "Dire_name" >> to Remove a directory
#    - rm -r "Dire_name" >> to Remove a directory with its content
#    - rm -rf "Dire_name" >> to force Remove a directory with its content
#
#    - cp "File_name" "Dire_path/" >> to Copy a file
#    - cp -r "Dire_name" "Dire_path/" >> to Copy a directory
#    - mv "Dire_name" "Dire_path/" >> to Move a directory
#
#    - mv "Dire_name" "New_Dire_name" >> to Rename a Directory
#    - cp -r "Dire_name" "New_Dire_name" >> to Make a copy with new name
#
#
# >> ls -l:
#    - d >> for Directory
#    - "-" >> for File
#    - r >> for Read
#    - w >> for Write
#    - x >> for Excute
#    - 3 Root - 3 Group - 3 Others
#
#
# >> Files commands:
#    - ls | grep -i "File_name" >> to show files and choose specific one
#    - grep -i "file_name" >> choose file with skipping case sensetivity
#    - ls | grep -i "file" | ./"file" >> search and open that directory
#    - sudo apt-cache search "file_name" >> search in all directories
#    - locate "file_name" >> to search for Directory with its extension
#    - find / -name "file_name" >> search in all directories
#    - find Desktop/ -name "file_name" >> search in the Desktop only
#    - find ~/Desktop/ -name "file_name" >> search in the Desktop only with home extension
#
#
# > curl "website" >> to get the index of the website
#
# >> curl www.google.com > google.txt
# >> cat google.txt | grep -i -o "[a-z0-9]*.google.com" | sort -u
#    - curl www.google.com > google.txt >> get the index "data" of www.google.com and save it to google.txt
#    - cat google.txt >> show the content of google.txt
#    - grep -i -o "[a-z0-9]*.google.com" >> only show content contain from a-z and 0-9 with .google.com
#    - sort -u >> to get it sorted and not repeated
#
#
# > head -n 10 "file_name" >> show first 10 rows of that file
#
# > tail -n 10 "file_name" >> show last 10 rows of that file
#
# > tail -f "file_name" >> show live data of that file
#
# > sudo apt install "file_name" >> to install a file
#
# >> linux task manager
#    - htop >> Visual task manager
#    - top >> usual task manager
#    - kill -9 "PID" >> to force ending program
#
#    - ps >> show small working prosses
#    - ps aux >> show all working prosses
#
#
# >> use && OR ; to do two commands in one line
#    - sudo apt update && sudo apt upgrade
#    - sudo apt update ; sudo apt upgrade
#
#
# >> use > to over write a file and >> to append to it
#   - echo "Hello" > test.txt ; cat test.txt
#   - echo "Hello World" > test.txt ; cat test.txt (overwrite the last command and print Hello World)
#
#   - echo "Hello World" > test.txt ; cat test.txt
#   - echo "Hello" >> test.txt ; cat test.txt (print the 2 lines)
#
#
# > tea "file_name" >> show you the content of that file
#
# >> curl www.google.com > google.txt | tea google.txt
#    - curl www.google.com > google.txt >> get HTML data, and save it
#    - tea google.txt >> show the content in external app
#
#
# > df -h >> show Device resources in human readable way
#
# >> Power Off, Restarting commands:
#   - poweroff >> to power off the device
#   - reboot >> to Restart the device
#
#
# >> stdin, stdout, and stderr:
#    - 0: stdin >> for standard input (Required input)
#    - 1: stdout >> for standard output (prented value)
#    - 2: stderr >> for standard error (any occured error)
#    - 2>&1 >> mean to replace all Errors with standard output
#    - (nc -v -z 192.168.1.1 1-1000 2>&1 | grep -i "succeeded") >> search and get the opened ports only
#
#
# > (apropos "command description") >> to search for commands doing this description like (apropos port scanning)
#
# > (whatis "command") >> to get a description of this command
#
# >> Start a service automatically:
#    - (sudo systemctl enable "service") >> enable the service when power on
#    - (sudo systemctl disable "service") >> to disable the service
#    - (sudo systemctl start "service") >> enable the service on this time
#
#
# >> echo command:
#    - (echo $HOME) >> to know the home path
#    - (echo $USER) >> to know the current working user
#    - (whoami) >> to know the current working user
#    - (var = "name") then (echo $var) >> print the value of the var
#    - (export var = "name") then (echo $var) >> print the value of the var
#    - OR (nano .bashrc) to add any var and save it
#
#
# >> Add your command:
#    - First add the path of your command
#    - (env) >> show the old configurations and PATH
#    - (export PATH=command_path:$PATH) >> to add another path for the commands
#    - (env) >> show the new added PATH
#    - (chmod +x flag) >> to make the file executable
#    - (flag) >> now you can run the flag
#    - take care it's not saved when you close the terminal
#    - you can save it by editting the bash (nano .bashrc) and add the path
#    - (nano .bashrc) then (export PATH=command_path)
#    - OR move your file to the executable path from (env)

# %%
# Flag code:

#!/bin/python3
e = "0"
a = list(range(1, 17))
for i in a:
	print(e.zfill(i))
	
a = "{ Horray! You Got The Flag }"
print(a)

e = "0"
a = list(range(1, 17))
a.reverse()

for i in a:
	print(e.zfill(i))

# %% [markdown]
# >> Creat "cls" command to clear the Terminal screen and history:
#    - (env) >> to get the path of saved commands
#    - (cd /usr/sbin) >> to go to the path of saved commands
#    - (nano cls) >> to create "cls" command
#    - In the "cls" file type (clear "Enter" > .zsh_history) and save the file
#    - Now your command is Ready to use (:

# %% [markdown]
# > (ls -l Desktop/ | tee des) >> mean to show the content of Desktop, show it in the terminal, and save it in a "des" file
#
# > (ls -l Desktop/ > des) >> mean to save the content of the Desktop in "des" file
#
# > (ls -l Dir >out 2>err) >> mean to save the content of the "Dir" in "out" file if there is any content, or type the Error massage in the "err" file
#
# > (ls -l "Dir_name" >out 2>err) >> mean type the content of "Dir" in "out" if found, type in "err" if the "Dir" is not found
#
# > (wc "file_name") >> to count the file NUM of "lines - Words - Char"
#
# >> Grep command:
#    - (cat "file_name" | grep -i "word") >> ignor case sensitive
#    - (cat "file_name" | grep -n "word") >> get matched words with line's number
#    - (cat "file_name" | grep -v "word") >> ignor matched words
#    - (cat "file_name" | grep "word") >> get matched words
#    - (cat "file_name" | grep "word\|word") >> get matched words
#    - (cat "file_name" | grep [char-cahrnum-num]) >> get matched words
#    - (cat "file_name" | grep -i -o "[a-z0-9]*.google.com") >> get all strings that contain from "a to z and 0 to 9" ending with .google.com
#    - (cat "file_name" | grep ^[char]) >> get all words strats with that "char"
#    - (cat "file_name" | grep ^char...) >> search for words starts with "char" and is "4 letters" like (grep ^pa.....d)
#    - (grep -o -i "word" file_name | wc -l) >> to count how many times that work appeared in the file_name
#
#
# >> Sed command:
#    - (sed s/old_word/New_word/ file_name) >> replace first matched word in the line with the New_word
#    - (sed s/old_word/New_word/g file_name) >> replace all matched word in the line with the New_word
#    - (sed s/else/welcome/ index.html) >> replace first "else" word in the line with "welcome" in the "index.html" file
#    - (sed s/pass/p@ssw0rd/g index.html | tee n.txt) >> replace all "pass" with "p@ssw0rd", print them, and save it in "n.txt" file
#
#
# >> Split command:
#    - (split -l Lines_num File_split Splitted_files) >> to split one file "File_split" by lines "Lines_num" into files "Splitted_files"
#    - (split -l 14 index.txt file-) >> mean to split the "index.txt" into "14 lines" per file and called then "file-aa - file-ab - .."
#
#
# >> Cut command:
#    - (cat index.txt | cut -d " " -f 1) >> show words of line till you find "space" seperator and get first word before the spcae from "index.txt" file
#    - (cat index.txt | cut -d " " -f 1,2,3) >> show words of line till you find "space" seperator and get first 3 words sperated by a space from "index.txt" file

# %% [markdown]
# # Linux Basics For Ethical Hackers:
#
# >> Directories:
#    - / >> is the Root dire
#
#    - /boot >> the Dire that has the Kernal
#
#    - /home >> The Dire that has the Users Directories
#      - (sudo adduser "user_name") >> to make a new User
#
#    - /proc >> the Dire that has the Internal Kernal Data
#
#    - /dev >> the Dire that has the Special Device files
#
#    - /sbin >> The Dire that has the executable files
#
#    - /usr >> The Dire that has executable files and programs files
#
#    - /lib >> the Dire that has the Libraries the executable files
#
#    - /etc >> The Dire that has the Configuration of the programs
#
#
# >> Basic Linux Commands:
#    - (pwd) >> print your working directory
#    - (pwd > home) >> to save your current path in a file
#    - (cd $home) >> will move you to the path in the "home" file
#
#    - (whoami) >> to know if you're a user or the Root
#
#    - (cd) >> change working directory
#    - (cd ..) >> go back one directories
#    - (cd ../..) >> go back 2 directories
#    - (cd /) >> go back to the Root dire
#    - (sudo find . -name apache2) >> . mean to search in the current dire
#
#    - (ls) >> list the files
#    - (ls -la) >> show all files include hiddens with long format
#
#    - (--help) >> getting help
#    - (man command) >> Manual of the command
#
#    - (time "commnad") >> to get the time needed to excute the command
#
#    - (locate "word / command") >> get matched files "not recommended"
#      - (sudo updatedb) >> to update Locate database
#
#    - (whereis "word / command") >> to get the command path "executable"
#
#    - (which "command") >> to get the command path or its describtion
#
#    - (find "path" "option" -name "word") >> to search for any thing
#      - (find / -type d -name etc) >> search in "Root" system for "etc dire"
#      - (find . -type f -name home) >> search in your "current dire ." for the "home file f"
#      - (find . -type f -name index.*) >> search in your "current dire ." for the "files" that has name "index." any extention
#      - (find . -name "??ss") >> search in your "current dire ." for the files that contain "4 letters" and the last 2 letters are "ss"
#      - (find . -name [p,n]ass) >> search in your "current dire ." for the files that "start with p or n" and end with "ass"
#      - (find . -name *ass) >> search in your "current dire ." for the files that "start with any letter" and end with "ass"
#
#    - (ls | grep -i "file_name") >> to get any "file_name" with ignoring the case sensetivity
#      - (cat index.html | grep -i -o "[a-z0-9]*.google.com" | sort -u) >> to get "any domain for google.com" sorted and not repeated
#
#    - (cat > "file_name") >> to make a file and type in it
#      - (cat > hack), (Ctrl+D) to quit editting the file
#      - (cat >> "file_name) >> to append new lines without overwriting
#
#    - (nano "file_name") >> to make a file and type in it "text editor"
#
#    - (touch "file_name") >> to make a new file
#
#
# >> Chapter 2:
#    - (nl "file_name") >> to Print the file content Countered with lines
#
#    - (head -n "NUM" "file_name" | nl) >> to print first "NUM" lines with Counter
#    - (head -n- "NUM" "File_name") >> Print the whole "File_name" with ignoring "NUM" of lines
#
#    - (tail -n "NUM" "file_name" | nl) >> to print last "NUM" lines with Counter
#    - (tail -n+ "NUM" "File_name") >> Print from the "NUM" to the Last of the "File_name"
#
#    - (more "File_name") >> show the file page by page (Arrows) or word by word (Enter)
#    - (less "File_name") >> show the file page by page (Space) or word by word (Arrows OR Enter) with more Functions
#      - (less "file_name") then type (/Word) to search for this word
#      - (less "File_name") then type (h) to open less manual
#
#    - (sed s/old_word/New_word/ file_name | tee file_name2) >> replace first matched word in the line with the "New_word", then print and save it to "file_name2"
#    - (sed s/old_word/New_word/g file_name) >> replace all matched word in the line with the "New_word"
#    - (sed s/old_word/New_word/"num" file_name) >> replace the word if there is "num" of this word in one line with the "New_word"
#      - (sed s/world/universe/2 file) >> replace "second world word" in the line if there are "2 or more world word in one line"
#
#
# >> Analyzing and Managing Networks:
#    - (ifconfig) OR (ip a)>> to show the Network Configurations
#    - (iwconfig) >> to show the Wireless status
#    - (watch -n 0.5 -d iwconfig) >> watching Wireless Status
#
#    - (sudo ifconfig eth0 192.168.142.10) >> to change your IP address
#    - (sudo ifconfig eth0 192.168.142.10 netmask 'netmask' broadcast 'broadcast') >> to change your IP, netmask, and broadcast
#    - (sudo ifconfig eth0 down) then (sudo ifconfig eth0 hw ether "MAC") then (sudo ifconfig eth0 up) >> to change eth0 MAC Address
#    - (sudo dhclient eth0) >> to renew your network data
#
#    - (host -t a google.com) >> to get the google "IP v4"
#    - (host google.com) >> to get the google "IP v4 - IP v6 - Mail Service"
#
#    - (dig google.com ns) >> to get the google "Name Server"
#    - (dig google.com mx) >> to get the google "Mail Service"
#    - (dig @8.8.8.8 google.com) >> to search from google DNS
#    - (sudo nano /etc/resolv.conf) >> to change your DNS
#    - (sudo nano /etc/hosts) >> to add local Hosts "Local fishing sites"
#
#
# >> Adding and Removing Softwares:
#    - IN GUI (Synaptic) to install softwares
#    - IN Terminal (Advanced Packaging Tool (apt)) to install softwares
#
#    - (sudo apt-cache search "package_name") >> to search in the apt repo
#    - (nano /etc/apt/sources.list) >> to see from where did apt git the packages
#
#    - (sudo apt remove "package_name") >> remove Binary files only
#    - (sudo apt purge "package_name") >> remove Binary and Configuration files
#    - (sudo apt autoremove "package_name") >> remove all files and Libraries
#
#    - (sudo apt update) >> check for updates
#    - (sudo apt upgrade) >> upgrade the software without deleting any files
#    - (sudo apt full-upgrade) >> upgrade and remove unrequired files

# %% [markdown]
# --------------------------------------------------------------------------------------

# %% [markdown]
# # Linux CyberTalents:
#
# >> Secure Shell (SSH):
#    - Networking protocol
#    - Allows secure communications
#    - Can secure any network service
#    - Typacally used for remote command line access
#    - Secure connection between two machines
#    - Allows remote administration of servers
#
#
# >> Basic Linux Commands:
#    - (whoami) >> prints out your current user
#    - (id) >> prints out your UID, GID, and all the groups you are in
#    - (hostname) >> prints out your machine's hostname
#    - (uname -a) >> prints out your OS kernel version
#
#    - (pwd) >> prints out your working directory
#    - (echo $PWD) >> prints out your working directory
#
#    - (ls) >> lists all the files/directories
#    - (ls -l) >> lists all the files/directories with long format
#    - (ls -a) >> lists all the hidden files/directories
#
#    - (cd) >> to Change your directory
#    - (cd ..) >> to go back one folder
#    - (cd ../tasks) >> to go back one folder and change the directory to tasks folder
#    - (cd ~) >> to go home directory
#    - (cd -) >> to go to the last directory you were in
#
#    - (mkdir) >> to make a new directory
#    - (touch) >> to make a new file
#
#    - (mv file_name New_file_name) >> to change the file name
#    - (mv file_name path) >> to move a file to another directory
#
#    - (rm file_name) >> to remove a file
#    - (rm -rf dire_name) >> to remove a directory
#
#    - (man command) >> to get the command manual
#
#
# >> Text Manipulation Tools: (IMPORTANT)
#    - (cat lines.txt | sort) >> to sort lines.txt file
#
#    - (cat lines.txt | uniq) >> to filter the duplicates
#
#    - (cat lines.txt | tr -d '\n') >> to delete the lines between rows
#
#    - (cut -b 1,2,3 lines.txt) >> to print first 3 bytes in each line
#    - (cut -d " " -f 1,3 lines.txt) >> to print first and third words in lines.txt
#
#    - (awk '{print}' lines.txt) >> to print the lines.txt
#    - (awk '/0/ {print}' lines.txt) >> print lines that contains num 0
#    - (awk '{print $1, $3}' lines.txt) >> print word 1 and 3 in lines.txt
#    - (awk '{print NR, $0}' lines.txt) >> print lines.txt with numbers
#
#    - (echo -n "text_you_want_to_encrypt" | base64) >> to encode the text
#    - (echo -n "encrypted_text" | base64 -d) >> to decrypt the text
#
#
# >> Users && Groups:
#    - (adduser user_name) >> to add a new user
#    - (deluser User_name) >> to delete a Created User
#
#    - (passwd User_name) >> to get a new Password
#
#    - (addgroup Group_name) >> to add a new group
#    - (delgroup Group_name) >> to delete a Created Group
#
#    - (usermod -a -G "Group_name" "User_name") >> to add user to a group
#    - (gpasswd -d "User_name" "group_name") >> to remove user from a group
#
#    - (groups User_name) >> to see the group that user is in
#
#    - (visudo) >> to add a specific permission to a specific user in the User Privileges by adding (user_name ALL=command_path)
#    - (visudo) >> in the group sudo permissions you can add a specific permission to a specific group (%group_name ALL=command_path)
#
#
# >> File Permissions:
#    - (chown User_name:Group_name File_name) >> to change ownweship and group of a file
#
#    - (chown User_name File_name) >> to change ownership of a user file
#
#    - (chgrp Group_name File_name) >> to change the ownership  of a group
#
#
# >> Process Maniputlation:
#    - (Start_your_command) then (Ctrl + z) then type (bg) >> to send a the process to the backgound
#
#    - (exec Command) >> excute the command then close the terminal
#
#    - (kill -15 Process_PID) >> to Terminate a process
#
#
# >> Network Communication:
#    - (ip -4 addr) >> to show your IP v4 address
#    - (ip -6 addr) >> to show your IP v6 address
#
#    - (netstat) >> working ports and process on the network
#    - (netstat -a) >> show Listening UDP or TCP connections
#    - (netstat -at) >> show Listening TCP connections
#    - (netstat -u) >> show Listening UDP connections
#    - (netstat -l) >> show active ports
#
#    - (curl -X POST url) >> send a POST request to the url
#    - (curl -X POST --data "data" url) >> send a POST request with data
#    - (curl -o file_name url) >> to save the response to file_name
#    - (curl -I url) >> to see the response's header
#    - (curl --header "header" url) >> to send a specific header
