# %%
<!-- First 10 Videos (1-10) -->

<!DOCTYPE html> <!-- Tell about the HTML V5 -->
<html>
  <head>
    <!-- Use the world standard language that supports Arabic -->
    <meta charset="UTF-8" />
    <title> Book Store </title>
    <!--
      This is multiple line comment !!
      Used to display discription information under the title
      -->
    <meta 
      name= "discription" 
      content= "This is our Book Store" />
    <style>
      body{
        background-color: greenyellow;
      }
    </style>
    <link rel="stylesheet" href="">
  </head>
  <body>
    <!-- Headings are used in Titles -->
    <h1> Book Outer Title </h1>
      <h2> Chapter Title Inside Book </h2>
        <h3> Story Title Inside Chapter </h3>
        
    <!-- This used in Paragraph -->
    <p> This is my Book Store, Welcome </p>
    <p> We have a Big Sale </p>
  </body>
</html>

# %%
<!-- Video 11 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <!--
      b => Bold
      Strong => Bold => Important text
      i => Italic
      em => Emphasized
      mark => Highlighted text
      u => Underlined
      small => Smaller text
      del => Deleted text
      ins => Inerted text
      sub => Subscript
      sup => Superscript
     -->
    <h1> Book Store </h1>
    <P> This is my <b>Book Store</b>, Welcome </P>
    <P> This is my <strong>Book Store</strong>, Welcome </P>
    <P> This is my <i>Book Store</i>, Welcome </P>
    <P> This is my <em>Book Store</em>, Welcome </P>
    <P> This is my Book Store, <mark>Welcome</mark> </P>
    <P> This is my Book Store, <u>Welcome</u> </P>
    <P> This is my Book Store, <small>Welcome</small> </P>
    <P> This is my <del>Book Store</del>, <small>Welcome</small> </P>
    <p> <del>$100</del> $80</p>
    <p>This is my <ins>Book Store</ins>, Welcome</p>
    <p>h<sub>2</sub>o , 10<sup>2</sup></p>
  </body>
</html>

# %%
<!-- Video 12 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <h1> Book Store </h1>
    <P> This is my Book Store, Welcome </P>
    <!-- 
        a is an Inline code
        target="_blank" used to open the link in new tab 
      -->
    <a href="https://google.com" target="_blank"> Google </a>
    <!-- title="text" to show text when you come closer the Link -->
    <a href="https://Facebook.com" title="Go to Facebook"> Facebook </a>
    <!-- Used to go to a sepicif line of your paragraph -->
    <a href="#Line_32" title="Go to Line_32 Paragraph"> Line_32 Paragraph </a>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p id="Line_32"> <mark>HI :)</mark> Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <p>Lorem ipsum dolor sit amet consectetur adipisicing elit. Quisquam dolorum aperiam adipisci ad ipsum nostrum repellat ratione. In temporibus eaque et numquam doloremque iste, saepe distinctio fuga, quis omnis molestias.</p>
    <!-- Click it to go to the Mail and mail Me.com email -->
    <a href="mailto:Me.com">Contact Me</a>
  </body>
</html>

# %%
<!-- Vidoe 13 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <!-- 
        src => source
        alt => Alternate text "show if the photo not shown"
    -->
    <h1> Book Store </h1>
    <P> This is my Book Store, Welcome </P>
    <img src="palastine.jpg" alt="Palastine Home" width="400px" height="400px">
  </body>
</html>

# %%
<!-- Video 14 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <h1> Book Store </h1>
    <P> This is my Book Store, Welcome </P>
    <!-- 
        ul => Unorderd List
        li => List Items
      -->
      <ul>
        <li>HTML</li>
        <li>CSS</li>
        <li>
          JS
          <ul>
            <li>Angular</li>
            <li>Reactjs</li>
            <li>Vuejs</li>
          </ul>
        </li>
      </ul>
      <!-- 
        ol => Orderd List
        reversed => Reverse the Order
        start => Start from position
        type => Type of Ordering
      -->
      <ol type="I">
        <Li>Name</Li>
        <Li>Address</Li>
        <Li>ID</Li>
      </ol>
      <!--
        dl => Description List
        dt => Term
        dd => Description of the term
      -->
    <dl>
      <dt>HTML</dt>
      <dd>Language of the Web</dd>
      <dd>The First Lan</dd>
      <dt>CSS</dt>
      <dd>Language of the Visuals</dd>
    </dl>
  </body>
</html>

# %%
<!-- Vidoe 15 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <h1> Book Store </h1>
    <P> This is my Book Store, Welcome </P>
    <!-- 
        thead => Table Header
        tbody => Table Body
        tfoot => Table Footer
        tr => Table Row
        th => Table Header Cell
        td => Table Data Cell
    -->
    <table border="1" cellpadding="10">
      <caption> Student Marks </caption>
      <thead>
        <tr>
          <th>First</th>
          <th>Last</th>
          <th>Marks</th>
        </tr>
      </thead>
      <tbody>
        <tr>
          <td>A</td>
          <td>B</td>
          <td>90</td>
        </tr>
        <tr>
          <td>C</td>
          <td>D</td>
          <td>80</td>
        </tr>
        <tr>
          <td>E</td>
          <td>F</td>
          <td>70</td>
        </tr>
      </tbody>
      <tfoot>
        <tr>
          <!-- colspan='2' used to Merge 2 columns -->
          <td colspan="2">Total</td>
          <td>240</td>
        </tr>
      </tfoot>
    </table>
  </body>
</html>

# %%
<!-- Video 16 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <h1> Book Store </h1>
    <P> This is my Book Store, Welcome </P>
    <!-- 
        span => in Inline Element
        <hr> => used to make a Horizontal Line and a block element
        <br /> => used to make a new line
    -->
    <span>Word</span>
    <hr>
    <p>This is a Second Paragraph, <br /> Test</p>
  </body>
</html>

# %%
<!-- Vidoe 17 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <!-- div => is a container for texts -->
    <div>
      <h1> Book Store </h1>
      <P> This is my Book Store, Welcome </P>
    </div>
    
    <dev class="Romantic">
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
    </dev>
    <hr />
    <dev class="Police">
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
    </dev>
    <hr />
    <dev class="Fantacy">
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
      <dev class="Book">
        <h3>Book Title</h3>
        <p>Book Description</p>
        <span>$100</span>
      </dev>
    </dev>
  </body>
</html>

# %%
<!-- Video 18 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <div>
      <h1> Book Store </h1>
      <P> This is my Book Store, Welcome </P>
      <!--
          &lt; => mean to type Less Than
          &gt; => mean to type Greater Than 
          &asymp; => mean to type Almost equal
          &amp; => mean to type &
          &copy; => mean to type Copyright sign
          For more search with HTML Entities
      -->
      <div> This is my &lt;p&gt; Div </div>
      <p> &asymp; &copy; &</p>
      <p> &amp; </p>
    </div>
  </body>
</html>

# %%
<!-- Video 19 -->

<!-- Video 18 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <!--
        They are divs but with its relative names
        header => used for the header
        nav => Navigation Bar
        section => Content of the website 
        aside => side bar
    -->
    <header> Head of Website</header>
    <nav>Link - Link - Link</nav>
    <section>
      <section></section>
      <aside></aside>
    </section>
    <footer>Footer</footer>
  </body>
</html>

# %%
<!-- Video 20 (Layout with Div and Classes)-->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <div class="header">
      <h2>Logo</h2>
      <ul>
        <li>Home</li>
        <li>About</li>
        <li>Services</li>
        <li>Contact Us</li>
      </ul>
    </div>
    <hr>
    <ul class="navigation">
      <li>Link</li>
      <li>Link</li>
      <li>Link</li>
      <li>Link</li>
    </ul>
    <hr>
    <div class="content"> content </div>
    <div class="sidebare"> Sidebare </div>
    <hr>
    <div class="footer"> Footer </div>
  </body>
</html>

# %%
<!-- Video 21 (Layout with Semantic Elements) -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <header>
      <h2>Logo</h2>
      <ul>
        <li>Home</li>
        <li>About</li>
        <li>Services</li>
        <li>Contact Us</li>
      </ul>
    </header>
    <hr>
    <nav>
      <li>Link</li>
      <li>Link</li>
      <li>Link</li>
      <li>Link</li>
    </nav>
    <hr>
    <section>
      <figure>
        <img src="palastine.jpg" alt="">
        <figcaption>Caption of the image</figcaption>
      </figure>
    </section>
    <article></article>
    <aside> Sidebare </aside>
    <hr>
    <footer> Footer </footer>
  </body>
</html>

# %%
<!-- Vid 22 - 23 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <div>
      <h1>Book Store</h1>
      <p>This is my Booke Store, Welcome</p>
    </div>
    <audio controls autoplay loop muted>
      <source src="./Arabian_Night.mp3" type="audio/mpeg">
      <!-- <source src="media/one_way_ticket.ogg" type="audio/ogg">
      <source src="media/one_way_ticket.wav" type="audio/wav"> -->
      Your Browser doesn't support Audio Tags
    </audio>
    
    <hr>
    
    <video controls autoplay loop muted width="400" height="200" poster="./palastine.jpg">
      <source src="./html.mp4" type="video/mp4">
      Your Browser doesn't support Video Tags
      <!-- used to make a subtitles for the video -->
      <track src="file.vtt" kind="subtitles" srclang="en" label="English">
      <track src="file.vtt" kind="subtitles" srclang="et" label="Italian">
    </video>
  </body>
</html>

# %%
<!-- Vid 24 - 32 (Form videos)-->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="utf-8" />
    <title> Book Store </title>
    <meta name="description" content="This is out Book Store">
  </head>
  <body>
    <div>
      <h1>Book Store</h1>
      <p>This is my Booke Store, Welcome</p>
    </div>
    <form action="" method="Post" novalidate target="_blank">
      <!-- 
            novalidate mean to don't check the form before sending
            method="Get" show the data in the search bar
            method="Post" didn't show anything
            Input is and Inline Block
            Self Closing Tag
            readonly >> available and sent every time
            disabled >> available and not sent
          -->
      <input type="hidden" value="os" name="Hidden" />

      <div>
        <label>Username</label>
        <input type="text" required placeholder="Username" name="user" value="OS" readonly />
      </div>

      <br> <!-- Mean to take a Horizontal space -->

      <div>
        <label for="sub">Subject</label>
        <input id="sub" type="text" name="subject" autofocus />
      </div>

      <br> <!-- Mean to take a Horizontal space -->

      <div>
        <label for="pass">Password</label>
        <input id="pass" type="password" required name="pass" minlength="10" maxlength="24" />
      </div>

      <br> <!-- Mean to take a Horizontal space -->

      <div>
        <label for="mail">Email</label>
        <input id="mail" type="email" required placeholder="Write a valid Email" value="o@com.sa" name="mail" disabled />
      </div>

      <br> <!-- Mean to take a Horizontal space -->

      <div>
        <label for="color">Color</label>
        <input id="color" type="color" name="color" />
      </div>

      <br> <!-- Mean to take a Horizontal space -->

      <div>
        <label for="range">Range</label>
        <input id="range" type="range" name="range" min="0" max="100" step="10" value="50" />
      </div>

      <br> <!-- Mean to take a Horizontal space -->
      
      <div>
        <label for="num">Number</label>
        <input id="num" type="number" name="number" min="0" max="100" step="10" value="50"/>
      </div>
      
      <hr> <!-- Mean to take a Horizontal line -->
      
      <dev>
        <input id="win" type="radio" name="os" value="Windows" checked/>
        <label for="win" >Windsows</label>
      </dev>
      
      <br> <!-- Mean to take a Horizontal space -->
          
      <dev>
        <input id="mac" type="radio" name="os" value="Mac OS"/>
        <label for="mac">Mac OS</label>
      </dev>
      
      <br> <!-- Mean to take a Horizontal space -->

      <dev>
        <input id="linux" type="radio" name="os" value="Linux"/>
        <label for="linux">Linux</label>
      </dev>
      
      <hr> <!-- Mean to take a Horizontal line -->
      
      <dev>
        <input id="win1" type="checkbox" name="os" value="Windows" />
        <label for="win1" >Windsows</label>
      </dev>
      
      <br> <!-- Mean to take a Horizontal space -->
          
      <dev>
        <input id="mac1" type="checkbox" name="os" value="Mac OS"/>
        <label for="mac1">Mac OS</label>
      </dev>
      
      <br> <!-- Mean to take a Horizontal space -->
      
      <dev>
        <input id="linux1" type="checkbox" name="os" value="Linux"/>
        <label for="linux1">Linux</label>
      </dev>
      
      <hr> <!-- Mean to take a Horizontal line -->
      
      <label for="book">Choose a Book</label>
      <select id="book" name="book" >
        <optgroup label="Police">
          <option value="1">Book 1</option>
          <option value="2">Book 2</option>
          <option value="3">Book 3</option>
          <option value="4">Book 4</option>
        </optgroup>
        <optgroup label="Romantic">
          <option value="5">Book 5</option>
          <option value="6">Book 6</option>
          <option value="7" selected>Book 7</option>
          <option value="8">Book 8</option>
        </optgroup>
      </select>
      
      <hr> <!-- Mean to take a Horizontal line -->
      
      <textarea name="subject" cols="20" rows="20" placeholder="Test Text">Hi</textarea>
      
      <hr> <!-- Mean to take a Horizontal line -->
      
      <div>
        <label>Uplaod</label>
        <input type="file" />
      </div>
      
      <hr>
      
      <div>
        <label>Search</label>
        <input type="search" />
      </div>
      
      <hr>
      
      <div>
        <label>Url</label>
        <input type="url" />
      </div>
      
      <hr>
      
      <div>
        <label>Date</label>
        <input type="date" />
      </div>
      
      <hr>
      
      <div>
        <label>Month</label>
        <input type="month" />
      </div>
      
      <hr>
      
      <div>
        <label>Time</label>
        <input type="time" />
      </div>
      
      <hr>
      
      <!-- Good Option for choosing a country than the select cause it have the search -->
      <input list="programming" name="prog"/>
      <datalist id="programming">
        <option value="Python">
        <option value="PHP">
        <option value="C#">
        <option value="C++">
        <option value="C">
        <option value="R">
      </datalist>
      
      <br> <!-- Mean to take a Horizontal space -->

      <input type="reset" value="Reset">
      <input type="submit" value="save">
    </form>
  </body>
</html>

# %%
<!-- Vid 33 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8" />
    <title>Book Store</title>
    <mata name="description" content="This is out Book Store">
  </head>
  <body>
    <q>This is an Inline Quote</q>
    <blockquote>This is a Block Quote</blockquote>
    
    <button type="button">Click Here</button>
    
    <!-- <wbr> used between the Long Link to make a Breaks on it -->
    
    <p>السلام 2 Welcome</p>
    <p><bdi>السلام</bdi> 2 Welcome</p>
  </body>
</html>

# %%
<!-- Vid 34 -->

<!DOCTYPE html>
<html>
  <head>
    <meta charset="UTF-8" />
    <title>Book Store</title>
    <mata name="description" content="This is out Book Store">
  </head>
  <body>
    <!-- <pre> make the code or text appeare with its syntax -->
    <code>
      var x = 10;
      var y = 20;
      console.log(x + y);
    </code>
    
    <pre>
      <code>
        var x = 10;
        var y = 20;
        console.log(x + y);
      </code>
    </pre>
    
    <p>
      This is
      P
      New Line
      New Line
    </p>    
    
    <pre> 
      This is
      P
      New Line
      New Line
    </pre>
    
    <iframe src"https://elzero.org/" width="500" height="500">Hi</iframe>
  </body>
</html>

# %%
<!-- Vid 36 -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <title>Book Store</title>
    <mata name="description" content="This is out Book Store">
  </head>
  <body>
    <form action="">
      <label for="user">Username</label>
      <input id="user" type="text" name="user" />
      <button>Send</button>
      <button>Rest</button>
    </form>
  </body>
</html>

# %% [markdown]
# ----------------------------------------------------------------------------------------------

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Nouvil</title>
    <link rel="stylesheet" href="index.css" />
  </head>
  <body>
    <h1>Names</h1>
    
    <p>Ahmed</p>
    <p>Hassan</p>
    <p>Mazen</p>
  
  </body>
</html>

--------------------------------------------------------------------
<!-- CSS Code -->

p{
  color: red;
}

h1{
  color:cadetblue;
  font-size: x-large;
}

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Nouvil</title>
    <link rel="stylesheet" href="index.css" />
  </head>
  <body>
    <!-- 
        Class linking in CSS use .name{}
        Class can be shared by multiple
        id linking in CSS use #name{}
        dev linking in CSS use dev p{}
    -->
    <h1 class="h1">Names</h1>
    
    <p class="p1">Ahmed</p>
    <p class="p1">Hassan</p>
    <p id="p2">Mazen</p>
    
    <dev>
      <p>Mohammed</p>
    </dev>
  
  </body>
</html>

--------------------------------------------------------------------
<!-- CSS Code -->

.h1{
  color: blueviolet;
}

.p1{
  color: forestgreen;
}

#p2{
  color: red;
}

dev p{
  color: yellow;
}

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Nouvil</title>
    <link rel="stylesheet" href="index.css" />
  </head>
  <body>
    <!-- 
        input linking in CSS called by input[type="text"]{}
    -->
    <input type="text" placeholder="text" />
    <input type="email" placeholder="email" />
    <br>
    <input type="submit" />
  </body>
</html>

--------------------------------------------------------------------
<!-- CSS Code -->

input[type="text"] {
  background-color: wheat;
}

input[type="email"] {
background-color: silver;
}

input[type="submit"] {
  background-color: greenyellow;
}

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Nouvil</title>
    <link rel="stylesheet" href="index.css" />
  </head>
  <body>
    <div class="x">
      <h1>Nouvil</h1>
      <p>www.nouvil.com <br> www.nouvil.com <br> www.nouvil.com</p>
    </div>
  </body>
</html>

--------------------------------------------------------------------
<!-- CSS Code -->

div{
  color: red;
  text-align: center;
}

h1{
  color: green;
  font-family: cursive, sans-serif;
  font-size: 32px;
  font-weight: 300;
}

p{
  color: orange;
  font-size: 16px;
  line-height: 20px;
  letter-spacing: 10px;
}

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <link rel="stylesheet" href="index.css" />
    <title>CSS</title>
  </head>
  <body>
    <div class="x">
      Palastine
    </div>
  </body>
</html>

--------------------------------------------------------------------
<!-- CSS Code -->

.x{
  height: 200px;
  width: 200px;
  border: 5px black solid;
  background-color: rgba(122, 108, 115, 0.2);
  background-image: url("pp.jpg");
  background-size: contain;
  background-repeat: no-repeat;
  /* if fixed mean to move the photo with you */
  background-attachment: scroll;
  background-position: center center;
  
  /* Inner Space */
        /* Top Right Bottom Left*/
  padding: 40px 40px 40px 60px;
  text-align: center;
  
  /* Outer Space */
  margin: 40px 60px 40px 60px;
}

*{
  padding: 0px;
  margin: 0px;
}

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <link rel="stylesheet" href="index.css" />
    <title>CSS</title>
  </head>
  <body>
    <a href="www.test.com">Test</a>
    <br>
    <div> Test1 </div>
    <div> Test2 </div>
    <div> Test3 </div>
    
    <span>Test 1</span>
    <span>Test 2</span>
    <span>Test 3</span>
  </body>
</html>

--------------------------------------------------------------------
<!-- CSS Code -->

a{
  text-decoration: underline;
  color: brown;
  cursor: -webkit-grab;
}
/* Chane the color of the link if the Cursor on it */
a:hover{
  color: blue;
  font-size: 20px;
}

a:visited{
  /* change the color of text when the link is visited */
  color: orange;
}

div{
  background-color: red;
  width: 200px;
  height: 20px;
  margin: 10px;
  padding: 5px;
  /* convert from Block to Inline Element */
  display: inline;
}

span{
  background-color: blue;
  width: 200px;
  height: 20px;
  margin: 10px;
  padding: 5 px;
  /* convert from Inline to Block Element */
  display: block;
}

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <link rel="stylesheet" href="index.css" />
    <title>CSS</title>
  </head>
  <body>
    <div class="dev1">Test1</div>
    <div class="dev2">
      Test2
      Test3
      Test4
      Test5
      Test6
      Test7
      Test8
      Test9 
      Test10 
      Test11
      Test12 
      Test13
    </div>
    
    <br>
    
    <ul>
      <li>First</li>
      <li>Second</li>
      <li>Third</li>
    </ul>
  </body>
</html>

--------------------------------------------------------------------
<!-- CSS Code -->

.dev1{
  /* Hide the element with its location */
  display: none;
  
  /* Hide the element but let its location */
  visibility: hidden;
}

.dev2{
  height: 100px;
  width: 100px;
  background-color: red;
  
  /* Hide the overflow text from showing */
  overflow: hidden;
  
  /*
    Give you a scrolling to show the rest of the list 
    Use (overflow: auto) is good for this case 
  */
  overflow: scroll;
}

ul{
  /* make the sign as empty circle */
  list-style-type: circle;
  
  /* make it as the Orderd List */
  list-style-type: decimal;
  
  /* make the sign inside the background color */
  list-style-position: inside;
  
  /* change the sign to the image */
  list-style-image: url("pp.jpg");
}

ul li{
  background-color: aliceblue;
}

# %% [markdown]
# ----------------------------------------------------------------------------

# %%
<!-- 
  We install the VS code in the Linux distribution
  Then we start the apache server (sudo service apache2 start)
  Finally we Save the (.html) file in (/var/www/html) 
  Open the Browser and type (127.0.0.1/.html) to open it
-->

<!DOCTYPE html>
<html>
  <head>
    <title>Test Page</title>
  </head>
  <body>
    <h1>Hello World!</h1>
    <!-- Mean you have XSS bug -->
    <p onclick="alert(1)">XSS Bug</p>
  </body>
</html>

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html lang="en">
  
  <head>
    <title>Test Page</title>  <!-- [1] --> 
    <meta charset="UTF-8">  <!-- [3] -->
    <meta charset="description" content="A simple web page">  <!-- [3] --> 
    <meta http.equiv="X-UA-compatigle" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.8"> 
  </head>
  
  <body>
    <form action="" method="POST" enctype="multipart/form-data">  <!-- [5] -->
      <input type="text" name="uname" placeholder="Enter your username" value="Hacked">
      <input type="password" name="pass" placeholder="Enter your password" value="Hacked">
      <input type="hidden" name="secret" value="This is secret">
      <input type="image" src="">
      <input type="file" name="file">
      <input type="submit" value="send">
    </form>
  </body>
</html>

<!-- 
  [1]: Title
  [2]: Meta tags
  [3]: Charachter set
  [4]: Charachter encoding
  [5]: Forms structure
  [6]: Forms encoding
  [7]: Demo ! 
-->

# %%
<!-- HTML Code -->

<!DOCTYPE html>
<html>
  
  <head>
    <meta charset="UTF-8">
    <title>Test Page</title>
  </head>
  
  <body>
    <input type="image" src="chrome://branding/content/firefox-wordmark.svg" onload="alert('On Load')">   <!-- [1] -->
    <br>
    <br>
    <input type="text" onclick="alert('On Click')" placeholder="Onclick">   <!-- [2] -->
    <br>
    <br>
    <input type="text" onmouseover="alert('On Mouse Over')" placeholder="Onmouseover">   <!-- [3] -->
    <br>
    <br>
    <input type="text" onmouseout="alert('On Mouse Out')" placeholder="Onmouseout">   <!-- [4] -->
    <br>
    <br>
    <input type="text" onfocus="alert('On Focus')" placeholder="Onfocus">   <!-- [5] -->
    <br>
    <br>
    <input type="image" src="chrome://branding/content/firefox-wordmark.svg" onerror="alert('On Error')">   <!-- [6] -->
    <br>
    <br>
    <input type="text" onkeyup="alert('On Key Up')" placeholder="Onkeyup">   <!-- [7] -->
    <br>
    <br>
    <input type="text" onkeydown="alert('On Key Down')" placeholder="Onkeydown">   <!-- [8] -->
    <br>
    <br>
    <input type="text" onkeypress="alert('On Key Press')" placeholder="Onkeypress">   <!-- [9] -->
    <br>
    <br>
  
    <!-- JS overview -->
    <script>
      var name = 'MO';  // Make a variable
      var age = 21;
      console.log(name);  // Showen in the console of the browser
      console.log(age);
      
      alert('Alert')     // Just show alert Message
      confirm('Confirm') // Like asking you to submit something
      prompt('Prompt')   // Give you a box to type in
      
    </script> 
  </body>
</html>

<!-- 
  Event Handlers:
    - onload      [1]
    - onclick     [2]
    - onmouseover [3]
    - onmouseout  [4]
    - onfocus     [5]
    - onerror     [6]
              
    - onkeyup     [7]
    - onkeydown   [8]
    - onkeypress  [9]
-->
